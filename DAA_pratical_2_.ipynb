# %% [markdown]
# <a href="https://colab.research.google.com/github/venky418/DAA-practicals/blob/main/DAA_pratical_2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time

def linear_search(arr, key):
    for i in range(len(arr)):
        if arr[i] == key:
            return i
    return -1


def binary_search(arr, key):
    low = 0
    high = len(arr) - 1

    while low <= high:
        mid = low + (high - low) // 2

        if arr[mid] == key:
            return mid
        elif arr[mid] < key:
            low = mid + 1
        else:
            high = mid - 1

    return -1


n = 100000
arr = list(range(1, n + 1))

key = int(input("Enter element to search: "))

start = time.perf_counter()
index = linear_search(arr, key)
stop = time.perf_counter()

print("\nLinear Search")
if index != -1:
    print("Element found at index", index)
else:
    print("Element not found")

print("Time Taken:", (stop - start) * 1_000_000, "microseconds")


start = time.perf_counter()
index = binary_search(arr, key)
stop = time.perf_counter()

print("\nBinary Search")
if index != -1:
    print("Element found at index", index)
else:
    print("Element not found")

print("Time Taken:", (stop - start) * 1_000_000, "microseconds")
